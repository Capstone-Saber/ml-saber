# %% [markdown]
# # 1 Import Libraries

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import to_datetime
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns

# %% [markdown]
# # 2 Load Data

# %%
# Mengambil file
file_path = 'household_power_consumption.txt'

# Mengambil data dari file
# Menggabungkan kolom Date & Time
df = pd.read_csv(file_path, sep=';', dayfirst=True,
                 infer_datetime_format=True,
                 low_memory=False, na_values=['nan', '?'])

df.head()
# Out:
#          Date      Time  Global_active_power  Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00                4.216                  0.418   234.84
# 1  16/12/2006  17:25:00                5.360                  0.436   233.63
# 2  16/12/2006  17:26:00                5.374                  0.498   233.29
# 3  16/12/2006  17:27:00                5.388                  0.502   233.74
# 4  16/12/2006  17:28:00                3.666                  0.528   235.68
#
#    Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# 0              18.4             0.0             1.0            17.0
# 1              23.0             0.0             1.0            16.0
# 2              23.0             0.0             2.0            17.0
# 3              23.0             0.0             1.0            17.0
# 4              15.8             0.0             1.0            17.0

# %% [markdown]
# # 3 Preprocess Data

# %%
# Menggabungkan kolom Date & Time
df['Datetime'] = pd.to_datetime(df['Date'] + " " + df['Time'])

df.head()
# Out:
#          Date      Time  Global_active_power  Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00                4.216                  0.418   234.84
# 1  16/12/2006  17:25:00                5.360                  0.436   233.63
# 2  16/12/2006  17:26:00                5.374                  0.498   233.29
# 3  16/12/2006  17:27:00                5.388                  0.502   233.74
# 4  16/12/2006  17:28:00                3.666                  0.528   235.68
#
#    Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3  \
# 0              18.4             0.0             1.0            17.0
# 1              23.0             0.0             1.0            16.0
# 2              23.0             0.0             2.0            17.0
# 3              23.0             0.0             1.0            17.0
# 4              15.8             0.0             1.0            17.0
#
#              Datetime
# 0 2006-12-16 17:24:00
# 1 2006-12-16 17:25:00
# 2 2006-12-16 17:26:00
# 3 2006-12-16 17:27:00
# 4 2006-12-16 17:28:00

# %%
df.to_csv('house_consumption_melted.csv', index=False)

# %% [markdown]
# # 4 Model Build

# %% [markdown]
# ## Process Melted Dataset

# %%
# Ambil Data
df = pd.read_csv('house_consumption_melted.csv', sep=',', infer_datetime_format=True, header=0)

# Convert 'Datetime' column to datetime type
df['Datetime'] = pd.to_datetime(df['Datetime'])

# Set 'Datetime' as the index
df.set_index('Datetime', inplace=True)

# Group by minute and then resample into 1-hour frequency while summing 'Sub_metering_3'
df_agg = df.resample('1H').agg({'Sub_metering_3': 'sum'})

df_agg
# Out:
#                      Sub_metering_3
# Datetime
# 2006-12-16 17:00:00           607.0
# 2006-12-16 18:00:00          1012.0
# 2006-12-16 19:00:00          1001.0
# 2006-12-16 20:00:00          1007.0
# 2006-12-16 21:00:00          1033.0
# ...                             ...
# 2010-12-11 19:00:00           788.0
# 2010-12-11 20:00:00           604.0
# 2010-12-11 21:00:00             0.0
# 2010-12-11 22:00:00             0.0
# 2010-12-11 23:00:00             0.0
#
# [34951 rows x 1 columns]

# %% [markdown]
# ## Select the Relevant Data

# %%
# Select relevant columns
data = df_agg[['Sub_metering_3']]

# Print the result
print(data)
# Out:
#                      Sub_metering_3
# Datetime
# 2006-12-16 17:00:00           607.0
# 2006-12-16 18:00:00          1012.0
# 2006-12-16 19:00:00          1001.0
# 2006-12-16 20:00:00          1007.0
# 2006-12-16 21:00:00          1033.0
# ...                             ...
# 2010-12-11 19:00:00           788.0
# 2010-12-11 20:00:00           604.0
# 2010-12-11 21:00:00             0.0
# 2010-12-11 22:00:00             0.0
# 2010-12-11 23:00:00             0.0
#
# [34951 rows x 1 columns]

# %% [markdown]
# ## Normalize Data

# %%
scaler = MinMaxScaler()
data_normalized = scaler.fit_transform(data)

print(data_normalized)
# Out:
# [[0.46945089]
#  [0.78267595]
#  [0.7741686 ]
#  ...
#  [0.        ]
#  [0.        ]
#  [0.        ]]

# %% [markdown]
# ## Create Sequences

# %%
# Function to create input sequences and labels
def create_sequences(data, seq_length):
    sequences, labels = [], []
    for i in range(len(data) - seq_length):
        seq = data[i:i+seq_length]
        label = data[i+seq_length]
        sequences.append(seq)
        labels.append(label)
    return np.array(sequences), np.array(labels)

# %%
BATCH_SIZE = 25
sequence_length = 24

# Create sequences and labels
X, y = create_sequences(data_normalized, sequence_length)

# %% [markdown]
# ## Splits The Data

# %%
split_time = int(len(data) * 0.8)
train_data, test_data = X[:split_time], X[split_time:]
train_target, test_target = y[:split_time], y[split_time:]
# Out:
# array([[[0.05877804],
#         [0.05568445],
#         [0.67130704],
#         ...,
#         [0.89636504],
#         [0.870843  ],
#         [0.89095128]],
#
#        [[0.05568445],
#         [0.67130704],
#         [0.05955143],
#         ...,
#         [0.870843  ],
#         [0.89095128],
#         [0.86001547]],
#
#        [[0.67130704],
#         [0.05955143],
#         [0.10054138],
#         ...,
#         [0.89095128],
#         [0.86001547],
#         [0.24439288]],
#
#        ...,
#
#        [[0.23743233],
#         [0.12683681],
#         [0.03016241],
#         ...,
#         [0.        ],
#         [0.60943542],
#         [0.4671307 ]],
#
#        [[0.12683681],
#         [0.03016241],
#         [0.42614076],
#         ...,
#         [0.60943542],
#         [0.4671307 ],
#         [0.        ]],
#
#        [[0.03016241],
#         [0.42614076],
#         [0.        ],
#         ...,
#         [0.4671307 ],
#         [0.        ],
#         [0.        ]]])

# %%
# Reshape data for LSTM (samples, time steps, features)
train_data = train_data.reshape((train_data.shape[0], train_data.shape[1], 1))
train_target = train_target.reshape((train_target.shape[0], train_target.shape[1], 1))

# %% [markdown]
# ## Build The Model

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(64, return_sequences=True, input_shape=(sequence_length, 1)),
    tf.keras.layers.LSTM(64),
    tf.keras.layers.Dense(20, activation="relu"),
    tf.keras.layers.Dense(10, activation="relu"),
    tf.keras.layers.Dense(24)
])

# Summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 24, 64)            16896
#
#  lstm_3 (LSTM)               (None, 64)                33024
#
#  dense_3 (Dense)             (None, 20)                1300
#
#  dense_4 (Dense)             (None, 10)                210
#
#  dense_5 (Dense)             (None, 24)                264
#
# =================================================================
# Total params: 51694 (201.93 KB)
# Trainable params: 51694 (201.93 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.Huber(), metrics=["mae"])

# %% [markdown]
# ### Callback Function

# %%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if logs.get('mae') < 0.15:
            print('MAE terpenuhi')
            self.model.stop_training = True

# %% [markdown]
# ### Train the Model

# %%
model.fit(train_data, train_target, epochs=300, batch_size=BATCH_SIZE, callbacks=[myCallback()])
# Out:
# Epoch 1/300
# 1119/1119 [==============================] - 36s 27ms/step - loss: 0.0383 - mae: 0.2169
# Epoch 2/300
# 1119/1119 [==============================] - 30s 27ms/step - loss: 0.0317 - mae: 0.1933
# Epoch 3/300
# 1119/1119 [==============================] - 30s 27ms/step - loss: 0.0310 - mae: 0.1897
# Epoch 4/300
# 1119/1119 [==============================] - 31s 28ms/step - loss: 0.0305 - mae: 0.1870
# Epoch 5/300
# 1119/1119 [==============================] - 30s 27ms/step - loss: 0.0300 - mae: 0.1847
# Epoch 6/300
# 1119/1119 [==============================] - 32s 29ms/step - loss: 0.0294 - mae: 0.1820
# Epoch 7/300
# 1119/1119 [==============================] - 31s 28ms/step - loss: 0.0284 - mae: 0.1774
# Epoch 8/300
# 1119/1119 [==============================] - 31s 27ms/step - loss: 0.0275 - mae: 0.1734
# Epoch 9/300
# 1119/1119 [==============================] - 30s 27ms/step - loss: 0.0270 - mae: 0.1705
# Epoch 10/300
# 1119/1119 [==============================] - 30s 27ms/step - loss: 0.0266 - mae: 0.1692
# Epoch 11/300
# 1119/1119 [==============================] - 31s 28ms/step - loss: 0.0263 - mae: 0.1682
# Epoch 12/300
# 1119/1119 [==============================] - 31s 28ms/step - loss: 0.0260 - mae: 0.1660
# Epoch 13/300
# 1119/1119 [==============================] - 30s 27ms/step - loss: 0.0258 - mae: 0.1650
# Epoch 14/300
# 1119/1119 [==============================] - 30s 27ms/step - loss: 0.0255 - mae: 0.1640
# Epoch 15/300
# 1119/1119 [==============================] - 31s 28ms/step - loss: 0.0252 - mae: 0.1624
# Epoch 16/300
# 1119/1119 [==============================] - 30s 27ms/step - loss: 0.0250 - mae: 0.1618
# Epoch 17/300
# 1119/1119 [==============================] - 30s 27ms/step - loss: 0.0248 - mae: 0.1604
# Epoch 18/300
# 1119/1119 [==============================] - 30s 27ms/step - loss: 0.0245 - mae: 0.1589
# Epoch 19/300
# 1119/1119 [==============================] - 31s 28ms/step - loss: 0.0244 - mae: 0.1585
# Epoch 20/300
# 1119/1119 [==============================] - 31s 28ms/step - loss: 0.0242 - mae: 0.1576
# Epoch 21/300
# 1119/1119 [==============================] - 30s 27ms/step - loss: 0.0240 - mae: 0.1567
# Epoch 22/300
# 1119/1119 [==============================] - 30s 27ms/step - loss: 0.0239 - mae: 0.1566
# Epoch 23/300
# 1119/1119 [==============================] - 31s 28ms/step - loss: 0.0237 - mae: 0.1553
# Epoch 24/300
# 1119/1119 [==============================] - 30s 27ms/step - loss: 0.0236 - mae: 0.1549
# Epoch 25/300
# 1119/1119 [==============================] - 32s 28ms/step - loss: 0.0233 - mae: 0.1538
# Epoch 26/300
# 1119/1119 [==============================] - 30s 27ms/step - loss: 0.0232 - mae: 0.1533
# Epoch 27/300
# 1119/1119 [==============================] - 31s 28ms/step - loss: 0.0231 - mae: 0.1527
# Epoch 28/300
# 1119/1119 [==============================] - 30s 27ms/step - loss: 0.0229 - mae: 0.1517
# Epoch 29/300
# 1119/1119 [==============================] - 30s 27ms/step - loss: 0.0228 - mae: 0.1512
# Epoch 30/300
# 1119/1119 [==============================] - 30s 27ms/step - loss: 0.0225 - mae: 0.1501
# Epoch 31/300
# 1118/1119 [============================>.] - ETA: 0s - loss: 0.0223 - mae: 0.1489MAE terpenuhi
# 1119/1119 [==============================] - 31s 28ms/step - loss: 0.0223 - mae: 0.1489

# %% [markdown]
# ### Test the Model

# %%
# Make predictions on test data
predictions = model.predict(test_data)
# Out:
# 218/218 [==============================] - 3s 10ms/step

# %%
# Inverse transform predictions to original scale
predictions = scaler.inverse_transform(predictions)
test_target_inverse = scaler.inverse_transform(test_target)

# %%
# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(df_agg.index[split_time+sequence_length:], test_target_inverse, label='Actual Value')
plt.plot(df_agg.index[split_time+sequence_length:], predictions, label='Predicted Value', linestyle='dashed')
plt.title('Sub Metering 3 Prediction using LSTM')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.show()

# %% [markdown]
# ## Test On Real Data

# %%
# Mengambil file
test_path = 'data_temp_iot.txt'

# Mengambil data dari file
df = pd.read_csv(test_path)

df.head(24)
# Out:
#        kWh
# 0    97.53
# 1   116.15
# 2   145.71
# 3    88.55
# 4    31.33
# 5     3.12
# 6     3.30
# 7     4.46
# 8     3.14
# 9     4.26
# 10    4.79
# 11  137.98
# 12  112.78
# 13   32.94
# 14   54.67
# 15   78.90
# 16   23.45
# 17   45.67
# 18   89.01
# 19   12.34
# 20   67.89
# 21   98.76
# 22   34.56
# 23   72.90

# %%
# Select relevant columns
data = df[['kWh']]

data_arrayed = np.array(data)
# Print the result
print(data_arrayed)
# Out:
# [[ 97.53]
#  [116.15]
#  [145.71]
#  [ 88.55]
#  [ 31.33]
#  [  3.12]
#  [  3.3 ]
#  [  4.46]
#  [  3.14]
#  [  4.26]
#  [  4.79]
#  [137.98]
#  [112.78]
#  [ 32.94]
#  [ 54.67]
#  [ 78.9 ]
#  [ 23.45]
#  [ 45.67]
#  [ 89.01]
#  [ 12.34]
#  [ 67.89]
#  [ 98.76]
#  [ 34.56]
#  [ 72.9 ]]

# %%
# Normalize the Data
data_normalized = scaler.fit_transform(data_arrayed)

# Print the generated data
print(data_normalized)
# Out:
# [[6.62108142e-01]
#  [7.92692335e-01]
#  [1.00000000e+00]
#  [5.99130374e-01]
#  [1.97839961e-01]
#  [0.00000000e+00]
#  [1.26236061e-03]
#  [9.39757346e-03]
#  [1.40262290e-04]
#  [7.99495056e-03]
#  [1.17119013e-02]
#  [9.45788625e-01]
#  [7.69058139e-01]
#  [2.09131075e-01]
#  [3.61526054e-01]
#  [5.31453819e-01]
#  [1.42576618e-01]
#  [2.98408023e-01]
#  [6.02356406e-01]
#  [6.46609159e-02]
#  [4.54239428e-01]
#  [6.70734273e-01]
#  [2.20492321e-01]
#  [4.89375131e-01]]

# %%
X, y = create_sequences(data_normalized, 1)
X
# Out:
# array([[[6.62108142e-01]],
#
#        [[7.92692335e-01]],
#
#        [[1.00000000e+00]],
#
#        [[5.99130374e-01]],
#
#        [[1.97839961e-01]],
#
#        [[0.00000000e+00]],
#
#        [[1.26236061e-03]],
#
#        [[9.39757346e-03]],
#
#        [[1.40262290e-04]],
#
#        [[7.99495056e-03]],
#
#        [[1.17119013e-02]],
#
#        [[9.45788625e-01]],
#
#        [[7.69058139e-01]],
#
#        [[2.09131075e-01]],
#
#        [[3.61526054e-01]],
#
#        [[5.31453819e-01]],
#
#        [[1.42576618e-01]],
#
#        [[2.98408023e-01]],
#
#        [[6.02356406e-01]],
#
#        [[6.46609159e-02]],
#
#        [[4.54239428e-01]],
#
#        [[6.70734273e-01]],
#
#        [[2.20492321e-01]]])

# %%
predictions = model.predict(X)
# Out:
# 1/1 [==============================] - 1s 867ms/step

# %%
predictions = scaler.inverse_transform(predictions)
# Print the predicted data
print("\nPredicted Data:")
print(predictions)
# Out:
# Predicted Data:
# [[123.46093  123.389244 122.743675 122.667145 123.33261  123.0068
#   123.01589  123.007996 122.9322   122.96072  122.93783  122.96554
#   122.55447  123.78011  122.7054   123.41899  123.4436   123.64677
#   122.65827  123.47162  123.00187  123.379395 122.99849  123.09154 ]
#  [134.91167  134.85272  133.9262   133.89816  134.7801   134.3562
#   134.32507  134.3251   134.24345  134.22276  134.16312  134.19351
#   133.70804  135.29866  133.87584  134.82149  134.92464  135.18172
#   133.85303  134.97585  134.3007   134.83954  134.34552  134.40338 ]
#  [145.27678  145.22922  144.04803  144.06369  145.14212  144.62912
#   144.56172  144.5689   144.48183  144.41673  144.32384  144.35672
#   143.80353  145.72546  143.98677  145.14299  145.31705  145.62317
#   143.98584  145.38931  144.52798  145.21303  144.61632  144.64253 ]
#  [115.75295  115.673096 115.217766 115.10926  115.62736  115.36842
#   115.40421  115.39109  115.31962  115.380806 115.3826   115.408356
#   115.04857  116.02552  115.18765  115.74337  115.71556  115.88177
#   115.1245   115.72789  115.39716  115.66554  115.361694 115.477776]
#  [ 48.984505  48.8236    49.69625   49.316685  48.85434   49.040207
#    49.30715   49.24326   49.1613    49.48686   49.661022  49.679527
#    49.677467  48.96253   49.736782  49.218086  48.778446  48.727688
#    49.54613   48.69745   49.34697   48.823704  49.05174   49.366653]
#  [ 12.109408  12.082417  11.881493  11.8493    12.063298  11.957029
#    11.96232   11.959524  11.935851  11.951025  11.94837   11.957867
#    11.812546  12.217226  11.86735   12.099421  12.100839  12.165341
#    11.846949  12.105947  11.958845  12.080075  11.953453  11.990849]
#  [ 12.109408  12.082417  11.881493  11.8493    12.063298  11.957029
#    11.96232   11.959524  11.935851  11.951025  11.94837   11.957867
#    11.812546  12.217226  11.86735   12.099421  12.100839  12.165341
#    11.846949  12.105947  11.958845  12.080075  11.953453  11.990849]
#  [ 12.109408  12.082417  11.881493  11.8493    12.063298  11.957029
#    11.96232   11.959524  11.935851  11.951025  11.94837   11.957867
#    11.812546  12.217226  11.86735   12.099421  12.100839  12.165341
#    11.846949  12.105947  11.958845  12.080075  11.953453  11.990849]
#  [ 12.109408  12.082417  11.881493  11.8493    12.063298  11.957029
#    11.96232   11.959524  11.935851  11.951025  11.94837   11.957867
#    11.812546  12.217226  11.86735   12.099421  12.100839  12.165341
#    11.846949  12.105947  11.958845  12.080075  11.953453  11.990849]
#  [ 12.109408  12.082417  11.881493  11.8493    12.063298  11.957029
#    11.96232   11.959524  11.935851  11.951025  11.94837   11.957867
#    11.812546  12.217226  11.86735   12.099421  12.100839  12.165341
#    11.846949  12.105947  11.958845  12.080075  11.953453  11.990849]
#  [ 12.109408  12.082417  11.881493  11.8493    12.063298  11.957029
#    11.96232   11.959524  11.935851  11.951025  11.94837   11.957867
#    11.812546  12.217226  11.86735   12.099421  12.100839  12.165341
#    11.846949  12.105947  11.958845  12.080075  11.953453  11.990849]
#  [143.19     143.1401   142.01007  142.01685  143.0559   142.56075
#   142.50069  142.50642  142.4204   142.36429  142.2781   142.31049
#   141.77078  143.62637  141.95097  143.06499  143.22475  143.52107
#   141.94562  143.29277  142.46884  143.1245   142.54836  142.58104 ]
#  [133.20892  133.14809  132.26337  132.22813  133.07785  132.66855
#   132.64339  132.64224  132.56148  132.54808  132.49391  132.52391
#   132.04951  133.5858   132.2148   133.12592  133.21738  133.46645
#   132.18839  133.26514  132.62056  133.13539  132.6582   132.7213  ]
#  [ 47.899807  47.745533  48.602222  48.236748  47.775944  47.96189
#    48.218296  48.157288  48.08156   48.395763  48.565872  48.583153
#    48.58447   47.87304   48.64086   48.126514  47.701424  47.646603
#    48.456608  47.620724  48.25742   47.74645   47.97257   48.27571 ]
#  [ 69.70797   69.57732   70.08018   69.79162   69.58617   69.65506
#    69.84159   69.79709   69.73323   69.9734    70.10072   70.11917
#    70.01271   69.75883   70.09532   69.86824   69.558624  69.55332
#    69.94439   69.49659   69.869286  69.578606  69.65854   69.906265]
#  [105.454414 105.36519  105.1681   105.01943  105.3345   105.168045
#   105.23806  105.21841  105.15422  105.25732  105.29173  105.31449
#   105.02763  105.66101  105.14904  105.48754  105.39134  105.50573
#   105.06575  105.382515 105.240364 105.36089  105.16341  105.307846]
#  [ 51.969765  51.771156  52.702507  52.24629   51.800434  51.972702
#    52.29165   52.21376   52.100857  52.486904  52.684254  52.710102
#    52.663353  51.98708   52.74846   52.237736  51.724045  51.698513
#    52.520588  51.63841   52.33534   51.768013  51.98693   52.36816 ]
#  [ 52.553688  52.42699   53.112747  52.815445  52.44869   52.593643
#    52.794117  52.747585  52.695004  52.950016  53.093746  53.107826
#    53.079193  52.54054   53.137108  52.73698   52.395153  52.345207
#    52.98289   52.32117   52.82734   52.430687  52.599045  52.848534]
#  [116.18959  116.110176 115.64401  115.537285 116.06382  115.801056
#   115.83534  115.82251  115.75077  115.810135 115.81054  115.836426
#   115.47366  116.46485  115.613434 116.17818  116.15332  116.321655
#   115.55117  116.166534 115.8279   116.10249  115.79423  115.90905 ]
#  [ 17.446487  17.462034  17.394775  17.431896  17.456968  17.44459
#    17.407696  17.418581  17.443338  17.412203  17.406109  17.403307
#    17.374632  17.448256  17.381702  17.42573   17.47005   17.457401
#    17.393934  17.462944  17.406948  17.467075  17.438768  17.411242]
#  [ 91.01145   90.91388   91.09162   90.89456   90.905876  90.87878
#    90.99243   90.96494   90.91558   91.07207   91.1512    91.168434
#    90.9977    91.11413   91.08854   91.10299   90.91593   90.950134
#    90.98105   90.87685   91.007965  90.91472   90.87703   91.05375 ]
#  [124.390915 124.320244 123.65183  123.57922  124.262314 123.92852
#   123.93436  123.9271   123.8508   123.87534  123.84949  123.877396
#   123.460266 124.71564  123.61257  124.34508  124.37605  124.5836
#   123.56741  124.405945 123.91949  124.31013  123.92     124.01021 ]
#  [ 46.963615  46.81658   47.664497  47.313667  46.84723   47.03671
#    47.28251   47.224487  47.15589   47.45864   47.62514   47.640915
#    47.649414  46.928825  47.701557  47.18403   46.773003  46.711853
#    47.523987  46.692112  47.32114   46.818485  47.046562  47.337215]]

# %% [markdown]
# # 5 Generate Save Model

# %% [markdown]
# ## Save the Model

# %%
run_model = tf.function(lambda x: model(x))
# This is important, let's fix the input size.
STEPS = 1
INPUT_SIZE = 24
concrete_func = run_model.get_concrete_function(
    tf.TensorSpec([STEPS, INPUT_SIZE], model.inputs[0].dtype))

# model directory.
MODEL_DIR = "model_kWh_4"
model.save(MODEL_DIR, save_format="tf", signatures=concrete_func)

converter = tf.lite.TFLiteConverter.from_saved_model(MODEL_DIR)
tflite_model = converter.convert()

# %% [markdown]
# ## Convert the Model to TFLITE

# %%
import pathlib
tflite_model_file = pathlib.Path('model_kWh_4.tflite')
tflite_model_file.write_bytes(tflite_model)
# Out:
# 213228
